# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
card = pd.read_csv('/content/drive/MyDrive/CARD-LANGCHAIN/data/card_data.csv')

# %% [markdown]
# ## 1. 연회비 데이터 전처리

# %%
card['국내_연회비'] = card['Annual_fee'].apply(lambda x:0 if '국내' not in x else x)

# %%
card['국내_연회비']
# Out:
# 0      국내 4만8천원, 해외 4만8천원, 가족겸용 없음
# 1               국내 1만2천원, 해외 1만2천원
# 2               국내 4만7천원, 해외 4만9천원
# 3       국내 1만5천원, 해외 1만5천원, 가족 5천원
# 4                   국내 1만원, 해외 1만원
#                   ...
# 161      국내 10만원, 해외 10만원, 가족겸용 없음
# 162             국내 4만1천원, 해외 4만2천원
# 163               국내 1만5천원, 해외 2만원
# 164               국내전용 없음, 해외겸용 없음
# 165             국내 1만5천원, 해외 1만5천원
# Name: 국내_연회비, Length: 166, dtype: object

# %%
card['국내_연회비'] = card['국내_연회비'].str.split(',').str[0]

# %%
card['해외_연회비'] = card['Annual_fee'].str.split(',').str[1]

# %%
card['Annual_fee']
# Out:
# 0      국내 4만8천원, 해외 4만8천원, 가족겸용 없음
# 1               국내 1만2천원, 해외 1만2천원
# 2               국내 4만7천원, 해외 4만9천원
# 3       국내 1만5천원, 해외 1만5천원, 가족 5천원
# 4                   국내 1만원, 해외 1만원
#                   ...
# 161      국내 10만원, 해외 10만원, 가족겸용 없음
# 162             국내 4만1천원, 해외 4만2천원
# 163               국내 1만5천원, 해외 2만원
# 164               국내전용 없음, 해외겸용 없음
# 165             국내 1만5천원, 해외 1만5천원
# Name: Annual_fee, Length: 166, dtype: object

# %%
card['국내_연회비'] = card['국내_연회비'].str.replace('국내','')

# %%
card['국내_연회비'] = card['국내_연회비'].str.replace('전용 없음','0',regex=False)

# %%
card['국내_연회비'] = card['국내_연회비'].str.replace('만원','0000',regex=False)

# %%
card['국내_연회비'] = card['국내_연회비'].str.replace('만','',regex=False)

# %%
card['국내_연회비'] = card['국내_연회비'].str.replace('천원','000',regex=False)

# %%
card['국내_연회비'].fillna('0',inplace=True)

# %%
card.astype({'국내_연회비':'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-613036234927> in <cell line: 1>()
# ----> 1 card.astype({'국내_연회비':'int'})
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6618                 else:
#    6619                     try:
# -> 6620                         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6621                     except ValueError as ex:
#    6622                         ex.args = (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow, squeeze)
#     756             values = values[0, :]  # type: ignore[call-overload]
#     757
# --> 758         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     759
#     760         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     235
#     236     try:
# --> 237         new_values = astype_array(values, dtype, copy=copy)
#     238     except (ValueError, TypeError):
#     239         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     180
#     181     else:
# --> 182         values = _astype_nansafe(values, dtype, copy=copy)
#     183
#     184     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#     131     if copy or arr.dtype == object or dtype == object:
#     132         # Explicit copy, or required since NumPy can't view from / to object.
# --> 133         return arr.astype(dtype, copy=True)
#     134
#     135     return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: ' 19천9백원': Error while type casting for column '국내_연회비'

# %%
card['국내_연회비'].isnull().sum()
# Out:
# 4

# %%
card['국내_연회비'][card['국내_연회비'] == '해외 18000']
# Out:
# 16    해외 18000
# Name: 국내_연회비, dtype: object

# %%
card['Annual_fee'].iloc[16]
# Out:
# '해외 1만8천원, 가족겸용 없음'

# %%
# 국내 금액 추출 함수
def extract_domestic_fee(fee_string):
    import re
    # 국내 금액만 추출
    match = re.search(r'국내 (?:(\d+)만)?(\d*)천?원?', fee_string)
    if match:
        # '만'과 '천' 단위 합산하여 숫자로 변환
        ten_thousand = int(match.group(1)) * 10000 if match.group(1) else 0
        thousand = int(match.group(2)) * 1000 if match.group(2) else 0
        return ten_thousand + thousand
    return 0  # 국내 금액이 없으면 0 반환

# 데이터프레임의 Annual_fee 열에서 국내 금액 추출
card['Domestic_Fee'] = card['Annual_fee'].apply(extract_domestic_fee)

# %%
def extracted_domestic_fee(fee_string):
  import re
  # 국내 금액만 추출
  match = re.search(r'국내 (?:(\d+)만)?(\d*)천?원?', fee_string)
  if match:
    # '만'과 '천'단위 합산해서 숫자로 변환
    ten_thousand = int(match.group(1)) * 10000 if match.group(1) else 0
    thousand = int(match.group(2)) * 1000 if match.group(2) else 0
    return ten_thousand + thousand
  return 0 # 국내 금액이 없으면 0 반환

card['Domestic_Fee'] = card['Annual_fee'].apply(extract_domestic_fee)

# %%
card['Domestic_Fee']
# Out:
# 0       48000
# 1       12000
# 2       47000
# 3       15000
# 4       10000
#         ...
# 161    100000
# 162     41000
# 163     15000
# 164         0
# 165     15000
# Name: Domestic_Fee, Length: 166, dtype: int64

# %%
card['Annual_fee']
# Out:
# 0      국내 4만8천원, 해외 4만8천원, 가족겸용 없음
# 1               국내 1만2천원, 해외 1만2천원
# 2               국내 4만7천원, 해외 4만9천원
# 3       국내 1만5천원, 해외 1만5천원, 가족 5천원
# 4                   국내 1만원, 해외 1만원
#                   ...
# 161      국내 10만원, 해외 10만원, 가족겸용 없음
# 162             국내 4만1천원, 해외 4만2천원
# 163               국내 1만5천원, 해외 2만원
# 164               국내전용 없음, 해외겸용 없음
# 165             국내 1만5천원, 해외 1만5천원
# Name: Annual_fee, Length: 166, dtype: object
