# %%
import pandas as pd
Untitled = pd.read_csv('/content/drive/MyDrive/CARD-LANGCHAIN/data/소분류.csv')
MainCategory = pd.read_csv('/content/drive/MyDrive/CARD-LANGCHAIN/data/대분류카테고리.csv')
CardInfo = pd.read_csv('/content/drive/MyDrive/CARD-LANGCHAIN/data/카드정보.csv')
CardPerfom = pd.read_csv('/content/drive/MyDrive/CARD-LANGCHAIN/data/카드실적.csv')

# %%
Untitled.head()
# Out:
#    subCtgId subCtgName  mainCtgId
# 0         1     항공마일리지          1
# 1         2         쇼핑          2
# 2         3       간편결제          2
# 3         4    포인트/캐시백          2
# 4         5        편의점          3

# %%
MainCategory.head()
# Out:
#    mainCtgId mainCtgName
# 0          1          항공
# 1          2     쇼핑/간편결제
# 2          3    편의점/대형마트
# 3          4     카페/베이커리
# 4          5          외식

# %%
CardInfo.head()
# Out:
#    cardId                        cardName  \
# 0       1           하나 트래블로그 SKYPASS 신용카드
# 1       2                   삼성카드 taptap O
# 2       3                        DA카드의정석Ⅱ
# 3       4  삼성카드 & MILEAGE PLATINUM(스카이패스)
# 4       5          현대카드ZERO Edition3(할인형)
#
#                                     Detail_summ_name
# 0                                ['항공마일리지', '언제나할인']
# 1  ['연회비지원', '포인트/캐시백', '카페/베이커리', '쇼핑', '통신', '대...
# 2  ['연회비지원', '언제나할인', '쇼핑', '레저', '프리미엄', '카페/베이커...
# 3  ['프리미엄', '쇼핑', '주유', '카페/베이커리', '편의점', '대중교통',...
# 4  ['연회비지원', '언제나할인', '대중교통', '간편결제', '편의점', '통신'...

# %%
CardInfo['Detail_summ_name']
# Out:
# 0                                    ['항공마일리지', '언제나할인']
# 1      ['연회비지원', '포인트/캐시백', '카페/베이커리', '쇼핑', '통신', '대...
# 2      ['연회비지원', '언제나할인', '쇼핑', '레저', '프리미엄', '카페/베이커...
# 3      ['프리미엄', '쇼핑', '주유', '카페/베이커리', '편의점', '대중교통',...
# 4      ['연회비지원', '언제나할인', '대중교통', '간편결제', '편의점', '통신'...
#                              ...
# 301                    ['주유', '관리비', '통신', '오토', '간편결제']
# 302                                               ['렌탈']
# 303                ['포인트/캐시백', '주유', '대중교통', '문화', '쇼핑']
# 304    ['포인트/캐시백', '바우처', '프리미엄', '카페/베이커리', '대형마트', ...
# 305              ['포인트/캐시백', '언제나할인', '카페/베이커리', '대중교통']
# Name: Detail_summ_name, Length: 306, dtype: object

# %%
CardPerfom.head()
# Out:
#    cardId                    annualfee          pervSales  performId
# 0       1  국내 4만8천원, 해외 4만8천원, 가족겸용 없음               조건없음          1
# 1       2               국내 1만원, 해외 1만원  직전 1개월 합계 30만원 이상          2
# 2       3           국내 1만2천원, 해외 1만2천원  직전 1개월 합계 30만원 이상          3
# 3       4           국내 4만7천원, 해외 4만9천원               조건없음          4
# 4       5   국내 1만5천원, 해외 1만5천원, 가족 5천원               조건없음          5
